# %% [markdown]
# <a href="https://colab.research.google.com/github/merttguney/AI_106/blob/main/AI106_8_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/zaferdemirkol/HerkesIcinYapayZeka/main/Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
X = df[["TV"]]
y = df["sales"]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
model = reg.fit(X, y)

# %%
model.intercept_
# Out:
# np.float64(7.032593549127695)

# %%
model.coef_
# Out:
# array([0.04753664])

# %% [markdown]
# $
# R^2 = 1 - \frac{\sum (y_i - \hat{y}_i)^2}{\sum (y_i - \bar{y})^2}
# $

# %%
model.score(X,y)
# Out:
# 0.611875050850071

# %%
y_tahmin= model.predict(X)

# %%
y_tahmin
# Out:
# array([17.97077451,  9.14797405,  7.85022376, 14.23439457, 15.62721814,
#         7.44616232,  9.76595037, 12.74649773,  7.44140866, 16.53041431,
#        10.17476548, 17.23871025,  8.16396559, 11.66741599, 16.73482186,
#        16.32125309, 10.25557777, 20.40940417, 10.32212907, 14.03474068,
#        17.41459582, 18.31779199,  7.6600772 , 17.88520856,  9.99412625,
#        19.52997632, 13.82557947, 18.44614092, 18.85970969, 10.38868036,
#        20.95607553, 12.39948025, 11.653155  , 19.65832525, 11.58185004,
#        20.85149492, 19.72012288, 10.58358059,  9.08142275, 17.87094757,
#        16.65876324, 15.44657891, 20.98935118, 16.86792445,  8.22576322,
#        15.35625929, 11.2966302 , 18.43663359, 17.83291826, 10.21279479,
#        16.53041431, 11.80527225, 17.31952254, 15.71278409, 19.52046899,
#        16.48763133,  7.37961102, 13.50708398, 17.05331735, 17.04856369,
#         9.57580381, 19.45391769, 18.4081116 , 11.91460652, 13.26464711,
#        10.31262174,  8.52999772, 13.65444756, 18.31779199, 17.3385372 ,
#        16.49713866, 12.25211667,  8.30657551, 13.18383482, 17.17691262,
#         7.83596277,  8.33985116, 12.76075872,  7.28929141, 12.54684384,
#        10.66439288, 18.43187992, 10.61210257, 10.28409975, 17.18166628,
#        16.21667248, 10.65963921, 12.29489965, 11.2300789 , 12.25211667,
#        13.41676436,  8.39214147, 17.38132017, 18.95953663, 12.13802873,
#        14.79532693, 16.4258337 , 15.82211837, 20.80395828, 13.45954734,
#        17.60474238, 21.12245377, 20.3523602 , 15.96472829, 18.3558213 ,
#        13.58789626,  8.22100956, 11.32990584,  7.65532354, 19.17345152,
#        17.76636696, 18.52219954, 15.38478127, 16.99627338, 10.74995883,
#        10.60259525, 13.6496939 , 10.66439288, 13.00794925,  7.95480437,
#        13.74952084,  7.92628239, 17.68080101, 12.88435399, 17.94225253,
#        11.17778859,  7.40337934, 10.84503211, 17.50491544,  9.86577732,
#         7.0658692 , 19.63931059,  7.43190133, 17.48114712,  8.78669558,
#         9.32861328,  8.24953154, 20.04337204,  9.07666909, 15.82211837,
#        10.52178296, 16.2404408 , 17.51442276, 12.00492614, 11.60561836,
#        13.7019842 , 18.44614092, 18.5935045 ,  8.83898589,  9.15748138,
#        20.37612852, 12.78452704, 16.4258337 , 15.17562006, 15.95997462,
#         7.22749377, 11.49628409, 14.15358229,  7.58877224, 13.29316909,
#        15.23266402, 11.10648363, 15.98849661, 14.80483426, 12.60388781,
#        18.17993573,  7.88349941, 16.86317079, 17.2719859 , 20.54726042,
#         9.40942557, 14.8523709 ,  7.9643117 , 15.0377638 , 17.60474238,
#        20.19548929, 18.84069503, 15.12332975, 20.18598196, 14.9046612 ,
#        14.47683144, 17.41934948,  9.70415274, 20.70413134, 19.09739289,
#        16.77760484, 13.66395489, 16.11684554, 20.62807271,  7.92152873,
#         8.91029085, 10.6216099 ,  7.85022376, 14.96170517, 14.14882862,
#         8.84849321, 11.51054508, 15.44657891, 20.51398478, 18.06584779])

# %%
7.03 + 30*0.04
# Out:
# 8.23

# %%
model.predict([[30]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8.45869276])

# %% [markdown]
# **Mean Absolute Error** (MAE)
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
#
# **Mean Squared Error** (MSE) karesi alınmış hataların ortalamasıdır:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
#
# **Root Mean Squared Error** (RMSE), karesi alınmış hataların ortalamasının karekökü:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$

# %%
yeni_veri = [[5],[90],[200]]
model.predict(yeni_veri)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([ 7.27027675, 11.31089119, 16.53992164])

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
MAE = mean_absolute_error(y, y_tahmin)
MSE = mean_squared_error(y,y_tahmin)
RMSE = np.sqrt(MSE)

# %%
y.mean()
# Out:
# np.float64(14.0225)

# %%
MAE
# Out:
# 2.549806038927486

# %%
MSE
# Out:
# 10.512652915656757

# %%
RMSE
# Out:
# np.float64(3.2423221486546887)

# %%
gercek_vs_tahmin = pd.DataFrame({"y": y,
                                                    "y_tahmin": model.predict(X)})

# %%
gercek_vs_tahmin
# Out:
#         y   y_tahmin
# 0    22.1  17.970775
# 1    10.4   9.147974
# 2     9.3   7.850224
# 3    18.5  14.234395
# 4    12.9  15.627218
# ..    ...        ...
# 195   7.6   8.848493
# 196   9.7  11.510545
# 197  12.8  15.446579
# 198  25.5  20.513985
# 199  13.4  18.065848
#
# [200 rows x 2 columns]

# %%
gercek_vs_tahmin["hata"] = gercek_vs_tahmin["y"] - gercek_vs_tahmin["y_tahmin"]

# %%
gercek_vs_tahmin
# Out:
#         y   y_tahmin      hata
# 0    22.1  17.970775  4.129225
# 1    10.4   9.147974  1.252026
# 2     9.3   7.850224  1.449776
# 3    18.5  14.234395  4.265605
# 4    12.9  15.627218 -2.727218
# ..    ...        ...       ...
# 195   7.6   8.848493 -1.248493
# 196   9.7  11.510545 -1.810545
# 197  12.8  15.446579 -2.646579
# 198  25.5  20.513985  4.986015
# 199  13.4  18.065848 -4.665848
#
# [200 rows x 3 columns]

# %%
gercek_vs_tahmin["hata_kare"]=gercek_vs_tahmin["hata"]**2

# %%
gercek_vs_tahmin
# Out:
#         y   y_tahmin      hata  hata_kare
# 0    22.1  17.970775  4.129225  17.050503
# 1    10.4   9.147974  1.252026   1.567569
# 2     9.3   7.850224  1.449776   2.101851
# 3    18.5  14.234395  4.265605  18.195390
# 4    12.9  15.627218 -2.727218   7.437719
# ..    ...        ...       ...        ...
# 195   7.6   8.848493 -1.248493   1.558735
# 196   9.7  11.510545 -1.810545   3.278073
# 197  12.8  15.446579 -2.646579   7.004380
# 198  25.5  20.513985  4.986015  24.860348
# 199  13.4  18.065848 -4.665848  21.770136
#
# [200 rows x 4 columns]

# %%
hata_kare_toplam = gercek_vs_tahmin["hata_kare"].sum()

# %%
mse = np.mean(gercek_vs_tahmin["hata_kare"])

# %%
mse  # MSE, modelin tahminlerinin gerçek değerlerden ne kadar uzak olduğunu ölçer. Daha düşük MSE daha iyi bir model uyumunu gösterir.
# Out:
# np.float64(10.512652915656757)

# %% [markdown]
# R-kare = 1 - (SSR / SST)

# %%
gercek_deger_ortalaması = np.mean(y)

# %%
gercek_deger_ortalaması
# Out:
# np.float64(14.0225)

# %%
gercek_deger_ortalamasından_sapma= y - gercek_deger_ortalaması

# %%
gercek_deger_ortalamasından_sapma
# Out:
# 0       8.0775
# 1      -3.6225
# 2      -4.7225
# 3       4.4775
# 4      -1.1225
#         ...
# 195    -6.4225
# 196    -4.3225
# 197    -1.2225
# 198    11.4775
# 199    -0.6225
# Name: sales, Length: 200, dtype: float64

# %%
SST = gercek_deger_ortalamasından_sapma**2

# %%
# R-kare = 1 - (SSR / SST)
1 - (hata_kare_toplam / SST.sum())
# Out:
# np.float64(0.611875050850071)

# %%
sns.kdeplot(gercek_vs_tahmin["hata"])
# Out:
# <Axes: xlabel='hata', ylabel='Density'>

# %%
sns.scatterplot(data=df,x=y,y=gercek_vs_tahmin["hata"])
plt.axhline(y=0, color='r', linestyle='--')

# %%
X = df[["TV"]]
y = df["sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)

# %%
len(X_test)
# Out:
# 60

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)

# %%
model.coef_  # Modelin katsayısını verir
# Out:
# array([0.04704165])

# %%
model.intercept_
# Out:
# np.float64(7.177057802578858)

# %%
MAE = mean_absolute_error(y_test, test_predictions)
MAE
# Out:
# 2.5480925983786147

# %%
MSE = mean_squared_error(y_test, test_predictions)
MSE
# Out:
# 10.318455423013349

# %%
np.linspace(0,300,60)
# Out:
# array([  0.        ,   5.08474576,  10.16949153,  15.25423729,
#         20.33898305,  25.42372881,  30.50847458,  35.59322034,
#         40.6779661 ,  45.76271186,  50.84745763,  55.93220339,
#         61.01694915,  66.10169492,  71.18644068,  76.27118644,
#         81.3559322 ,  86.44067797,  91.52542373,  96.61016949,
#        101.69491525, 106.77966102, 111.86440678, 116.94915254,
#        122.03389831, 127.11864407, 132.20338983, 137.28813559,
#        142.37288136, 147.45762712, 152.54237288, 157.62711864,
#        162.71186441, 167.79661017, 172.88135593, 177.96610169,
#        183.05084746, 188.13559322, 193.22033898, 198.30508475,
#        203.38983051, 208.47457627, 213.55932203, 218.6440678 ,
#        223.72881356, 228.81355932, 233.89830508, 238.98305085,
#        244.06779661, 249.15254237, 254.23728814, 259.3220339 ,
#        264.40677966, 269.49152542, 274.57627119, 279.66101695,
#        284.74576271, 289.83050847, 294.91525424, 300.        ])

# %%
plt.plot(X_train,y_train, "ob")

plt.plot(X_test,y_test, "or")

plt.plot(np.linspace(0,300,60),model.predict(np.linspace(0,300,60).reshape((-1,1))), color="orange")
plt.plot(X_test,test_predictions, "og")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
X = df.drop('sales', axis=1) # sütun bazında sales'ı çıkar geri kalanını X'e ata.
y = df['sales'] # sales'ı al y'ye ata.

# %%
X.head(3)
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)

# %%
len(X_train)
# Out:
# 140

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)

# %%
model.score(X_test, y_test) # bu modelde daha çok parametre devreye soktuğumuz için score'umuz arttı. Bu daha iyi bir model oldu.
# Out:
# 0.9185780903322445

# %%
MAE = mean_absolute_error(y_test,test_predictions)
MSE = mean_squared_error(y_test,test_predictions)

# %%
MAE
# Out:
# 1.213745773614481

# %%
2.5480925983786147 tek özellikli
# Out:
# 2.5480925983786147

# %%
MSE
# Out:
# 2.2987166978863796

# %%
10.3 Tek özellikli

# %%
model.coef_
# Out:
# array([ 0.04469599,  0.1875657 , -0.00032275])

# %%
quartet = pd.read_csv('anscombes_quartet1.csv')

# %%
quartet
# Out:
#        x      y
# 0   10.0   8.04
# 1    8.0   6.95
# 2   13.0   7.58
# 3    9.0   8.81
# 4   11.0   8.33
# 5   14.0   9.96
# 6    6.0   7.24
# 7    4.0   4.26
# 8   12.0  10.84
# 9    7.0   4.82
# 10   5.0   5.68

# %%
def model_olustur(x,y):
  model_quartet1 = LinearRegression()
  X_q1 = x
  y_q1 = y
  model_quartet1.fit(X_q1, y_q1)
  print(model_quartet1.coef_)
  MAE = mean_absolute_error(y_q1, model_quartet1.predict(X_q1))
  MSE = mean_squared_error(y_q1, model_quartet1.predict(X_q1))
  print(MAE)
  print(MSE)

# %%
model_olustur(quartet[["x"]], quartet["y"])
# Out:
# [0.50009091]
# 0.837404958677686
# 1.2511536363636366

# %%
quartet['pred_y'] = 3 + 0.5 * quartet['x']
quartet['residual'] = quartet['y'] - quartet['pred_y']

# %%
quartet
# Out:
#        x      y  pred_y  residual
# 0   10.0   8.04     8.0      0.04
# 1    8.0   6.95     7.0     -0.05
# 2   13.0   7.58     9.5     -1.92
# 3    9.0   8.81     7.5      1.31
# 4   11.0   8.33     8.5     -0.17
# 5   14.0   9.96    10.0     -0.04
# 6    6.0   7.24     6.0      1.24
# 7    4.0   4.26     5.0     -0.74
# 8   12.0  10.84     9.0      1.84
# 9    7.0   4.82     6.5     -1.68
# 10   5.0   5.68     5.5      0.18

# %%
sns.scatterplot(data=quartet,x='x',y='y')
sns.lineplot(data=quartet,x='x',y='pred_y',color='red')
plt.vlines(quartet['x'],quartet['y'],quartet['y']-quartet['residual'])

# %%
sns.kdeplot(quartet['residual'])
# Out:
# <Axes: xlabel='residual', ylabel='Density'>

# %%
sns.scatterplot(data=quartet,x='y',y='residual')
plt.axhline(y=0, color='r', linestyle='--')

# %%
quartet = pd.read_csv('anscombes_quartet2.csv')

# %%
quartet
# Out:
#        x     y
# 0   10.0  9.14
# 1    8.0  8.14
# 2   13.0  8.74
# 3    9.0  8.77
# 4   11.0  9.26
# 5   14.0  8.10
# 6    6.0  6.13
# 7    4.0  3.10
# 8   12.0  9.13
# 9    7.0  7.26
# 10   5.0  4.74

# %%
model_olustur(quartet[["x"]], quartet["y"])
# Out:
# [0.5]
# 0.9679338842975209
# 1.2523900826446281

# %%
quartet.columns = ['x','y']

# %%
quartet['pred_y'] = 3 + 0.5 * quartet['x']
quartet['residual'] = quartet['y'] - quartet['pred_y']

# %%
sns.scatterplot(data=quartet,x='x',y='y')
sns.lineplot(data=quartet,x='x',y='pred_y',color='red')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.kdeplot(quartet['residual'])
# Out:
# <Axes: xlabel='residual', ylabel='Density'>

# %%
sns.scatterplot(data=quartet,x='y',y='residual')
plt.axhline(y=0, color='r', linestyle='--')

# %%
quartet = pd.read_csv('anscombes_quartet4.csv')

# %%
model_olustur(quartet[["x"]], quartet["y"])
# Out:
# [0.49990909]
# 0.902727272727273
# 1.249317272727273

# %%
quartet['pred_y'] = 3 + 0.5 * quartet['x']
quartet['residual'] = quartet['y'] - quartet['pred_y']

sns.scatterplot(data=quartet,x='x',y='y')
sns.lineplot(data=quartet,x='x',y='pred_y',color='red')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.kdeplot(quartet['residual'])
# Out:
# <Axes: xlabel='residual', ylabel='Density'>

# %%
sns.scatterplot(data=quartet,x='y',y='residual')
plt.axhline(y=0, color='r', linestyle='--')

# %%
len(X)
# Out:
# 200

# %%
final_model = LinearRegression()

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_hat = final_model.predict(X)

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(16,6))

axes[0].plot(df['TV'],df['sales'],'o')
axes[0].plot(df['TV'],y_hat,'o',color='red')
axes[0].set_ylabel("Satış")
axes[0].set_title("TV")


axes[1].plot(df['radio'],df['sales'],'o')
axes[1].plot(df['radio'],y_hat,'o',color='red')
axes[1].set_ylabel("Satış")
axes[1].set_title("Radio")


axes[2].plot(df['newspaper'],df['sales'],'o')
axes[2].plot(df['newspaper'],y_hat,'o',color='red')
axes[2].set_ylabel("Satış")
# Out:
# Text(0, 0.5, 'Satış')

# %%
residuals = y_hat - y

# %%
sns.scatterplot(x=y,y=residuals)
plt.axhline(y=0, color='r', linestyle='--')

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
coeff_df = pd.DataFrame(final_model.coef_, X.columns, columns = ['Coefficient'])
coeff_df
# Out:
#            Coefficient
# TV            0.045765
# radio         0.188530
# newspaper    -0.001037
